# %% [markdown]
# # <center>Laboratorium 2<br>Metody Numeryczne</center>

# %% [markdown]
# Biblioteki niezbędne do wykonania zadania:

# %%
import main
import random
import numpy as np
import scipy
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ***Zadanie 1.***
# Zdefiniuj w notatniku funkcję $f(x)= x^{3} - 3x$ i sporządź jej wykres dla argumentów z przedziału:
# 1. $x\in<-1,1>$
# 2. $x\in<-5,5>$
# 3. $x\in<0,5>$
#
# ***Wskazówki***
# Jako argumentu funkcji można użyć numpy array.
#
# Do wizualizacji wyników w Pythonie używa się pakietu [Matplotlib](https://matplotlib.org/). Działanie tego pakietu prezentuje przykład:

# %%
x = np.linspace(-10,10)
# inicjalizacja wektora f(x) = sin(x)
y = np.sin(x)
plt.plot(x, y, label ='sin(x)')
plt.show()

# %% [markdown]
# Wspierając się dokumentacją [Matplotlib](https://matplotlib.org/) dodaj do wykresu etykiety osi, tytuł, grid i legendę.

# %%
x1 = np.linspace(-1,1)
x2=np.linspace(-5,5)
x3=np.linspace(0,5)

y1= ((x1**3) - (3*x1))
y2= ((x2**3) - (3*x2))
y3= ((x3**3) - (3*x3))

plt.figure(1)
plt.plot(x1, y1, label ='1.1')
plt.title("Tytuł nr 1")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.figure(2)
plt.plot(x2, y2, label ='1.2')
plt.title("Tytuł nr 2")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.figure(3)
plt.plot(x3, y3, label ='1.3')
plt.title("Tytuł nr 3")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Komentarz do zadania 1:
# Zdefiniowano 3 funkcję, o wzorze y= ((x**3) - (3*x)), ale dla róznych przedziałów x.
# Następnie dodano 3 osobne wykresy, które zawierają siatke, tytyl, legende, podpis osi x i y.

# %% [markdown]
# ***Zadanie 2.***
# Dla funkcji z zadania pierwszego używając wektora $x \in <-10,10>$ wyrysuj wykres dla argumentów:
# 1. $x\in<-1,1>$
# 2. $x\in<-10,-1>$
# 3. $x\in<1,10>$
#
# Używając do tego funkcji: [ylim](https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.ylim.html), [xlim](https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.xlim.html), [axis](https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.axis.html)

# %%
def f(x):
  return ((x**3) - (3*x))

zakres_x = np.linspace(-10, 10)
zakres_y = f(zakres_x)

plt.figure(1)
plt.xlim(-1,1)
plt.ylim(-4,4)
plt.plot(x, f(x), label ='1.1')
plt.title("Tytuł nr 1")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.figure(2)
plt.plot(x, f(x), label ='1.2')
plt.xlim(-10,-1)
"plt.ylim(-470,4)"
plt.title("Tytuł nr 2")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.figure(3)
plt.plot(x, f(x), label ='1.3')
plt.axis([1, 10, -100, 100])
plt.title("Tytuł nr 3")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Komentarz do zadania 2:
# Jest to funkcja z zadania 1. dla której zmieniony został x. W tym zadaniu jest x wektorem oraz zmienione zakresy osi X widoczne. Użyto również xlim, ylim oraz axis.

# %% [markdown]
# ***Zadanie 3.***
# Oblicz ilość ciepła, które wydzieli się podczas hamowania jeżeli opisuje je zależność:
#
# $Q = \cfrac{mv^2}{2}$
#
# jeżeli $m = 2500g$, $v = 60km/h$, wypisz wynik oraz podaj w kilokaloriach i dżulach. Wykreśl wykresy które zobrazują zmianę ilości ciepła w procesie hamowania dla ciała o masie $3000g$ i prędkości $v\in<200,0>km/h$, przedstawiając ciepło hamowania na pierwszym w skali liniowej na drugim w skali logarytmicznej.
#
# ***Wsakzówka:*** Do stworzenia wykresów z osią logarytmiczną skorzystaj z funkcji: [semilogy](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.semilogy.html), [xlim](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.xlim.html?highlight=xlim#matplotlib.pyplot.xlim) i [figure](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.figure.html?highlight=figure#matplotlib.pyplot.figure) z pakietu *Matplotlib*.

# %%
m1=2.5
v1=np.linspace(0,16.67)
dżulQ1= (m1 * (v1**2)) /2
kcalQ1=dżulQ1/4184
m2=3
v2=55.56
dżulQ2= (m2 * (v2**2)) /2
kcalQ2=dżulQ2/4184

plt.figure(1)
plt.plot(v1, dżulQ1, label ='dzul')
plt.title("Tytuł nr 1")
plt.xlabel("v")
plt.ylabel("Q")
plt.legend()
plt.grid(True)

plt.figure(2)
plt.plot(v1, kcalQ1, label ='kcal')
plt.title("Tytuł nr 2")
plt.xlabel("Prędkość")
plt.ylabel("Energia")
plt.legend()
plt.grid(True)

plt.figure(3)
plt.semilogy(v1, dżulQ1, label='Dżul')
plt.title("Tytuł nr 3")
plt.xlabel("Prędkość v [m/s]")
plt.ylabel("Energia kinetyczna Q [J]")
plt.legend()
plt.grid(True)

plt.figure(4)
plt.semilogy(v1, kcalQ1, label='kcal')
plt.title("Tytuł nr 4")
plt.xlabel("v")
plt.ylabel("Energia")
plt.legend()
plt.grid(True)


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# W zadaniu 3. nalezało przekonwerotwać wpierw dane na jednostki Si, w celu posiadania wyniku w Dżulach, a następnie przekonwetowano to na kcal dzielac przez 4187. Dodano 4 rożne wykresy. 1. przedstawia cieplo w dzulach w skali liniowej, drugi w kcal w skali liniowej, trzeci w dzulach w sklai logarytmicznej a czwarty w kcal w sklai logarytmicznej. Wykrresy zawieraja tytyl, legende, podpisane osie oraz siatkę.

# %% [markdown]
# ***Zadanie 4.***
# Częstą praktyką szczególnie w dziedzinie analizy danych, statystyce, uczeniu maszynowym, itp. jest tworzenie na podstawie biblioteki [Matplotlib](https://matplotlib.org/) własnych szablonów wykresów stworzonych na podstawie funkcji. Najprostszy przykład to przeładowanie funkcji plot tak by wykres miał czerwony kolor:

# %%
def my_plot(x,y,xlabel,ylabel,title,label):
    if x.shape != y.shape or  min(x.shape)==0:
        return None
    fig, ax = plt.subplots()
    ax.plot(x, y, 'r', label=label)
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)
    ax.legend()
    return fig

x = np.linspace(-10,10)
# inicjalizacja wektora f(x) = sin(x)
y = np.sin(x)
my_plot(x,y,'x','y','Funkcja sin', 'sin(x)')

# %% [markdown]
# Zaimplementuj funkcję *compare_plot* tak, aby na jednym wykresie zostały narysowane dwie serie danych za pomocą metody [plot](https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot).
#
# - Pierwsza seria powinna być rysowana kolorem **niebieskim** z grubością linii równą `4`.
# - Druga seria powinna być rysowana kolorem **czerwonym** z grubością linii równą `2`.
#
# Domyślnie wykres powinien zawierać **legendę**.
# Dodatkowo użytkownik powinien mieć możliwość ustawienia następujących parametrów:
# - x1 - wektor wartości osi x dla pierwszego wykresu,
# - y1 - wektor wartości osi y dla pierwszego wykresu,
# - x2 - wektor wartości osi x dla drugiego wykresu,
# - y2 - wektor wartości osi x dla drugiego wykresu,
# - xlabel - opis osi x,
# - ylabel - opis osi y,
# - title - tytuł wykresu ,
# - label1 - nazwa serii z pierwszego wykresu,
# - label2 - nazwa serii z drugiego wykresu.
#
# Jeżeli nie da się wyrysować danych należy zwrócić wartość None.

# %%
def compare_plot(x1:np.ndarray,y1:np.ndarray,x2:np.ndarray,y2:np.ndarray,
                 xlabel: str,ylabel:str,title:str,label1:str,label2:str):

    if x1.shape != y1.shape or x2.shape != y2.shape  or  min(x1.shape)==0 or min(x2.shape)==0:
        return None
    fig, ax = plt.subplots()
    ax.plot(x1, y1, color='blue', linewidth=4, label=label1)
    ax.plot(x2, y2, color='red', linewidth=2, label=label2)
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)
    ax.legend()
    ax.grid(True)
    
    return fig

# %% [markdown]
# Funkcja została stworzona, tak jak w wskazówce powyżej, tylko że jest rozszerzona o kolejny wykres, ponieważ ma na celu porównanie dwóch wykresów. uzyto funkcji subplots z biblioteki "plt", aby stworzyć dwie funkcje na jednym wykresie. Funkcje, które są porówywane będą róznić się kolorem oraz grubością linii.

# %% [markdown]
# ***Zadanie 5***
# Za pomocą funkcji *compare\_plot* rozwiąż graficznie równanie: $f(x) = g(x)$, gdzie:
# $f(x) = x+2$
# $g(x) = x^2 -2sin(x) + 3$

# %%
def f(x):
    return x + 2

def g(x):
    return x**2 - 2 * np.sin(x) + 3

daneX = np.linspace(-2, 3, 400)
daneY_F = f(daneX)
daneY_G = g(daneX)

wykres = compare_plot(
    x1=daneX,
    y1=daneY_F,
    x2=daneX,
    y2=daneY_G,
    xlabel="x",
    ylabel="y",
    title='tYTYŁ',
    label1="tytyl1",
    label2="tytul2"
)

if wykres:
    plt.show()

# %% [markdown]
# W zadaniu 5. użyto funkcji compare_plot z zadania 4.. Wpierw zdefiniowano funkcje f i g. Określono jak ma wyglądać oś X(zakres + krok). Kolejnym etapem było przypisanie danych i wstawienie ich do funkcji. Można zauważyć że funkcje różnią się grubością linii oraz kolorem.

# %% [markdown]
# ***Zadanie 6.***
# Innym przydatnym sposobem prezentowania wykresów jest [subplot](https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.subplot.html), czyli wyrysowanie obok siebie kilku wykresów. Zaimplementuj funkcję parallel_plot tak by obok siebie wyrysowane zostały dwa standardowe ploty i użytkownik mógł podać parametry:
# - x1 - wektor wartości osi x dla pierwszego wykresu,
# - y1 - wektor wartości osi y dla pierwszego wykresu,
# - x2 - wektor wartości osi x dla drugiego wykresu,
# - y2 - wektor wartości osi x dla drugiego wykresu,
# - x1label - opis osi x dla pierwszego wykresu,
# - y1label - opis osi y dla pierwszego wykresu,
# - x2label - opis osi x dla drugiego wykresu,
# - y2label - opis osi y dla drugiego wykresu,
# - title - tytuł wykresu,
# - orientation - parametr przyjmujący wartość '-' jeżeli subplot ma posiadać dwa wiersze albo '|' jeżeli ma posiadać dwie kolumny.
#
# Jeżeli nie da się wyrysować danych należy zwrócić wartość None.

# %%
def parallel_plot(x1:np.ndarray,y1:np.ndarray,x2:np.ndarray,y2:np.ndarray,
                  x1label:str,y1label:str,x2label:str,y2label:str,title:str,orientation:str):
    if len(x1) != len(y1) or len(x2) != len(y2):
        return None
    if orientation == '-':
        rows, cols = 1, 2
    elif orientation == '|':
        rows, cols = 2, 1
    else:
        return None
    fig, axes = plt.subplots(rows, cols)
    axes[0].plot(x1, y1, color='orange')
    axes[0].set_xlabel(x1label)
    axes[0].set_ylabel(y1label)
    axes[0].grid(True)

    axes[1].plot(x2, y2, color='green')
    axes[1].set_xlabel(x2label)
    axes[1].set_ylabel(y2label)
    axes[1].grid(True)
    return fig

# %% [markdown]
# W zadaniu 6. użyto subplot zamiast subplots. Funkcje działają podobnie, lecz inaczej się je implementuje. Dodany został warunek z długością jaką mają wektory x,y, taki że każdy punkt musi mieć P(x,y), nie moze byc np P(x,None). Dodadkowo wprowadzono tutaj parametr orientacji, który może być taki "-" lub taki "|". Są tworzone obok siebie dwa odzielne wykresy, którym można przypisać inne dane,właściwości jak np. kolor.

# %% [markdown]
# ***Zadanie 7.***
# Skorzystaj z funkcji *parallel_plot* i utwórz dwa wykresy:
# - na pierwszym przedstaw [spiralę logarytmiczną](https://pl.wikipedia.org/wiki/Spirala_logarytmiczna) w szerokim zakresie wartości,
# - na drugim zaprezentuj jej przebieg w pobliżu zera.

# %%
a = 0.5
b = 0.2

    
theta1 = np.linspace(0, 500, 10000)
x1 = a * np.exp(b * theta1) * np.cos(theta1)
y1 = a * np.exp(b * theta1) * np.sin(theta1)

    
theta2 = np.linspace(0, 10, 10000)
x2 = a * np.exp(b * theta2) * np.cos(theta2)
y2 = a * np.exp(b * theta2) * np.sin(theta2)

wykres = parallel_plot(
    x1, y1,
    x2, y2,
    x1label="x", y1label="y",
    x2label="x", y2label="y",
    title="tytul",
    orientation='-' )

plt.show()

# %% [markdown]
# Skorzystano ze stworzonej poprzednio funkcji. Wykresy przedstawiają spirale logarytmiczną, ale dla róznych skali. Mianowicie druga jest w pobliżu zera. Dodano też liczbę 10000 w linspace, która decyduje o ilości punktów na wykresie, czyli gdy jest bardzo mało to byłyby to łamane między punktami konkretnymi.

# %% [markdown]
# ***Zadanie 8.***
# Zaimplementuj funkcję *log\_plot* która będzie tworzyć wykres w skalach logaritmicznych. Skale logarytmiczne mają być ustawione zgodnie z parameterem *log\_axis* gdzie wartość:
# - 'x' oznacza skale logarytmiczną na osi x,
# - 'y' oznacza skale logarytmiczną na osi y,
# - 'xy' oznacza skale logarytmiczną na obu osiach.
#
# Dodatkowo użytkownik ma mieć możliwość ustawienia parametrów:
# - x - wektor wartości osi x,
# - y - wektor wartości osi y,
# - xlabel - opis osi x,
# - ylabel - opis osi y,
# - title - tytuł wykresu.

# %%
def log_plot(x:np.ndarray,y:np.ndarray,xlabel:np.ndarray,ylabel:str,title:str,log_axis:str):
    if x.size != y.size:
        return None
    fig, ax = plt.subplots()
    ax.plot(x,y)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    if log_axis == 'x':
        ax.set_xscale('log')
    elif log_axis == 'y':
        ax.set_yscale('log')
    elif log_axis == 'xy':
        ax.set_xscale('log')
        ax.set_yscale('log')

# %% [markdown]
# Komentarz do zadania 8:
# Jest to funkcja zwracająca wykres zaprojektowana tak, aby osie wykresu były logarytmiczne. Można wybrać które: czy tylko x, czy tylko y, czy obie xy.

# %% [markdown]
# **Zadanie 9.**
# Wykorzystaj funkcję *log_plot*, aby ponownie zilustrować wyniki z Zadania 3.
# Przedstaw na wykresach różne warianty funkcji opisującej ilość ciepła podczas hamowania, korzystając z logarytmicznych skal osi (`'x'`, `'y'`, `'xy'`).

# %%
m1=2.5
v1=np.linspace(0.1, 16.67, 100)
dzulQ1 = (m1 * (v1**2)) / 2
#kcalQ1 = dzulQ1 / 4184"
log_plot(
    x=v1,
    y=dzulQ1,
    xlabel="v",
    ylabel="E",
    title="title",
    log_axis='x'
)

log_plot(
    x=v1,
    y=dzulQ1,
    xlabel="v",
    ylabel="E",
    title="title",
    log_axis='y'
)


log_plot(
    x=v1,
    y=dzulQ1,
    xlabel="v",
    ylabel="E",
    title="title",
    log_axis='xy'
)

# %% [markdown]
# Komentarz do zadania 9:
# Użyto funkcji stworzonej w zadaniu 8. w celu odwtorzenia wykresów z zadania 3. lecz tym razem przy uzyciu osi logarytmicznych w wariancjach z róznymi osiami logarytmicznymi. Pominięto wykresy dla Qkcal, ponieważ są analogiczne jak Qdżul.

# %% [markdown]
# **Zadanie 10.**
# Skorzystaj z funkcji *semilogx*, aby narysować wykres funkcji
# $$
# f(x) = \cos\bigl(2\pi x\bigr)
# $$
# w zakresie od co najmniej $-10^2$ do $10^0$.
#
# Do wygenerowania wartości funkcji użyj trzech różnych kroków:
# - pierwszy krok około `0.02`,
# - dwa pozostałe nieznacznie większe.
#
# ***Wartości wygeneruj przy pomocy *np.arange*.***
#
# Narysuj wykresy według schematu:
# - węzły (punkty, w których obliczono wartości funkcji) oznacz kropkami,
# - połącz je liniami przerywanymi.
#
# Zaobserwuj, jak zmienia się kształt wykresu przy zwiększaniu kroku.
# Dla porównania przygotuj również wykres bez zastosowania skali logarytmicznej.
#
# Całość umieść w układzie siatki `2x2` przy użyciu *subplot*.
# Nie zapomnij o dodaniu tytułów osi oraz poszczególnych wykresów.

# %%
f = lambda x: np.cos(2*np.pi*x)
Xstart=0.01
Xend=1
step1=0.02
step2=0.05
step3=0.08

x1=np.arange(Xstart,Xend,step1)
y1=(f(x1))

x2=np.arange(Xstart,Xend,step2)
y2=(f(x2))

x3=np.arange(Xstart,Xend,step3)
y3=(f(x3))

plt.subplot(2, 2, 1)
plt.semilogx(x1, y1, 'o--')
plt.title('tytyl')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)


plt.subplot(2, 2, 2)
plt.semilogx(x2, y2, 'o--')
plt.title('tytyl')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

plt.subplot(2, 2, 3)
plt.semilogx(x3, y3, 'o--')
plt.title('tytyl')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(x1, y1, 'o--')
plt.title('tytyl')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Komentarz do zadania 10:
# Przy pomocy funkcji lambda zwracamy jaką wartośc ma mieć funkcja w zależnosci od argumentu, a następnie te argumenty określamy na 3 sposoby, przy pomocy np. arange. Te 3 sposoby róznią się krokiem o jaki zmienia się kolejny argument na osi OX. Dla 3 wykresów użyto semilogx, w celu otrzymania skali logarytmicznej, a dla ostaniego skala jest liniowa. Warto dodać również o zastosowaniu przerywanej linii zamiast ciągłej jak w poprzednich przykładach. W tym celu użyto 'o--' przy określaniu wykresu plt.plot.

# %% [markdown]
# Materiały uzupełniające:
# - [Scipy Lecture Notes](http://www.scipy-lectures.org/index.html)
# - [NumPy for Matlab users](https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html#numpy-for-matlab-users)
# - [Python Tutorial - W3Schools](https://www.w3schools.com/python/default.asp)
# - [NumPy](https://www.numpy.org)
# - [Matplotlib](https://matplotlib.org/)
# - [Anaconda](https://www.anaconda.com/)
# - [Learn Python for Data Science](https://www.datacamp.com/learn-python-with-anaconda?utm_source=Anaconda_download&utm_campaign=datacamp_training&utm_medium=banner)
# - [Learn Python](https://www.learnpython.org/)
# - [Wujek Google](https://google.pl) i [Ciocia Wikipedia](https://pl.wikipedia.org/wiki/Wikipedia:Strona_g%C5%82%C3%B3wna)
